# %%
# install libraries

# %pip install pygam

from pygam import LinearGAM, s, f, l
import pandas as pd
import patsy as pt
import numpy as np

# get data

training_data = pd.read_csv("https://raw.githubusercontent.com/dustywhite7/econ8310-assignment1/main/assignment_data_train.csv")

test_data = pd.read_csv("https://raw.githubusercontent.com/dustywhite7/econ8310-assignment1/main/assignment_data_test.csv")
# Out:
# Requirement already satisfied: pygam in C:\Users\kirkp\AppData\Local\Programs\Python\Python313\Lib\site-packages (0.12.0)
# Requirement already satisfied: numpy>=1.5.0 in C:\Users\kirkp\AppData\Local\Programs\Python\Python313\Lib\site-packages (from pygam) (2.1.3)
# Requirement already satisfied: progressbar2<5,>=4.2.0 in C:\Users\kirkp\AppData\Local\Programs\Python\Python313\Lib\site-packages (from pygam) (4.5.0)
# Requirement already satisfied: scipy<1.17,>=1.11.1 in C:\Users\kirkp\AppData\Local\Programs\Python\Python313\Lib\site-packages (from pygam) (1.14.1)
# Requirement already satisfied: python-utils>=3.8.1 in C:\Users\kirkp\AppData\Local\Programs\Python\Python313\Lib\site-packages (from progressbar2<5,>=4.2.0->pygam) (3.9.1)
# Requirement already satisfied: typing_extensions>3.10.0.2 in c:\Users\kirkp\AppData\Local\Programs\Positron\resources\app\extensions\positron-python\python_files\lib\ipykernel\py3 (from python-utils>=3.8.1->progressbar2<5,>=4.2.0->pygam) (4.15.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
eqn = "trips ~ hour + day + month + year"

y, x = pt.dmatrices(eqn, data = training_data)

model = LinearGAM(s(0) + s(1) + s(2) + s(3)) # init and fit model to spline based nonlinear for all params
"""
y = training_data['trips'].values # dep var vals
x = training_data[['hour', 'day', 'month', 'year']].values # indep vars vals
"""

modelFit = model.gridsearch(np.asarray(x), y) # fits model
#sd
# Out:
# 100% (11 of 11) |########################| Elapsed Time: 0:00:02 Time:  0:00:020:00

# %%
#xPred = test_data[['hour', 'day', 'month', 'year']].values # indep vars vals

#xPred = x.append(xPred)

xPred = pt.build_design_matrices([x.design_info], test_data)

pred = model.predict(xPred[0]) # prediction for each hour of a year after final year of data

# %%
pd.DataFrame(data = pred, columns = ['trips requested per hour'])
# Out:
# ---------------------------------------------------------------------------
#
# TypeError                                 Traceback (most recent call last)
#
# Cell In[23], line 1
#
# ----> 1 np.array(data = pred, columns = ['trips requested per hour'])
#
#
#
# TypeError: array() got an unexpected keyword argument 'data'
